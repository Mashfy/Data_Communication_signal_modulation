# %% [markdown]
# <h3><center>Name: Badrul Alam Siddique Masfy</center></h3> <h3><center>Reg no: 2017331060</center></h3>

# %% [markdown]
# # **Task #00**
#
# ### **Signal-01: Signals and Plotting the signal.**

# %% [markdown]
# #### **Signals:** Anything that carries information can be called as signal. It can also be defined as a physical quantity that varies with time, temperature, pressure or with any independent variables such as speech signal or video signal.
#
# #### The process of operation in which the characteristics of a signal Amplitude shape,phase,frequency,etc. undergoes a change is known as signal processing.

# %%
#@title Libraries import
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import butter, lfilter, freqz
import math
from matplotlib.pyplot import figure
import seaborn as sns

# %% [markdown]
# #### **Plotting a simple sinusoidal signal**
# #### Now consider this sinusoidal signal:
# **y = sin(x)**

# %%
t = np.linspace(-np.pi,np.pi,100)
p = np.sin(t)

fig = plt.figure(figsize = (18, 6))
ax = fig.add_subplot(1, 2, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.plot(t,p, 'b-', label='y=sin(t)')
plt.legend(loc='upper right')


q = np.sin(2*t)
r = np.sin(3*t)

# fig = plt.figure(figsize = (8, 6))
ax = fig.add_subplot(1, 2, 2)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')


plt.plot(t,p, 'b-', label='y=sin(t)')
plt.plot(t,q, 'c-', label='y=sin(2t)')
plt.plot(t,r, 'm-', label='y=sin(3t)')


plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# #### **Plotting a complex valued signal**
# #### Now consider the complex valued signal:
#
# ### **x(t) = e<sup>j100πt </sup>**

# %% [markdown]
# ### Plotting such a signal as if it were a real valued signal results in a Python warning that complex numbers are casted to real by discarding the imaginary parts. To see everything we have to plot both the real and imaginary part of the signal.

# %%
t = np.linspace(-0.02, 0.05, 1000)

p = np.exp(2j*np.pi*50*t).real
q = np.exp(2j*np.pi*50*t).imag


fig = plt.figure(figsize = (12, 6))
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')


plt.plot(t,p, 'b-', label='real x(t)')
plt.plot(t,q, 'c-', label='img) x(t)')


plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# ### **Signal-02: Basic Properties of a Signal.**

# %% [markdown]
# #### **Reflection:** Let's consider a signal sin(t) ; the reflected signal is described by sin(-t). Thus, the reflected signal assumes at time –t the value of the original signal that occurs at time t.

# %%
#@title Reflection Code
t = np.arange(-(4*np.pi),4*np.pi,0.1)

p = np.sin(t)
q = np.sin(-t)


fig = plt.figure(figsize = (12, 6))
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')


plt.plot(t,p, 'b-', label='y=sin(t)')
plt.plot(t,q, 'c-', label='y=sin(-t))')


plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### **Shifting:**
# ####Let   **y=$\frac{1}{√(2π)}$e<sup>-t<sup>2</sup>/2</sup>**    be an original signal. To obtain the shifted signal, for a shift t<sub>0</sub>=2, the value of the original signal that took place at t must now occur at t+t<sub>0</sub> . If t<sub>0</sub> is positive, the shifted signal is called a delayed signal.

# %%
#@title Shifting Code
t = np.linspace(-4, 4, 100)
p = 1/(2 * np.pi)**0.5 * np.exp(-t**2 / 2)
q = 1/(2 * np.pi)**0.5 * np.exp(-(t-2)**2 / 2)


# setting the axes at the centre
fig = plt.figure(figsize = (10, 6))
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot the functions, with labels
plt.plot(t,p, 'b-', label='not shifted')
plt.plot(t,q, 'c-', label='shifted')


plt.legend(loc='upper left')

# show the plot
plt.show()

# %% [markdown]
# ### **Periodicity:**
# ###A continuous signal is said to be periodic if there exists such a time interval T that x(t+T)= x(t); for all t. The smallest time T is known as the period. It should be noted that if a signal is periodic with the period T, it is also periodic for any integer multiple of T. In below, the Periodicity of sine fuction is shown.

# %%
#@title Periodicity Code
t = np.arange(-(4*np.pi),4*np.pi,0.1)
p = np.sin(2*(np.pi)+t)
q = np.sin(t)


fig = plt.figure(figsize = (8, 6))
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.plot(t,p, 'b-', linewidth=4, label='x(t+T)')
plt.plot(t,q, 'c-', linewidth=2, label='x(t)')


plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# # **Task #01**
#
# ### **A program to simulate the analog-digital signal using Pulse Code Modulation.**

# %% [markdown]
# ### **Pulse code modulation:** Pulse code modulation is a digital scheme for transmitting analog data. It converts an analog signal into digital form. Using PCM, it is possible to digitize all forms of analog data, including full-motion video, voice, music, telemetry, etc.

# %%
#Modulation
fs=1000
T=1/fs
L=5001
t=np.linspace(0,L-1,L)*T

#input Signal
f0=1
sig0=(1+np.sin(2*np.pi*f0*t))/2
    
#Quantization
q=8
sig1=np.array(np.round(sig0*q))
sig1=np.int_(sig1)

#Binary Encoding and binary to serial converter
v=4
tx=np.empty(L,dtype=object)

for i in range(L):
    tx[i]=np.binary_repr(sig1[i], width=v)


#Demodulation
sig2=np.empty(L,dtype=object)
  
for i in range(L):
    sig2[i]=int(tx[i],2)
    
sig2=sig2/q
    
#Low Pass Filter
cutoff=f0
fs=fs
order=5
nyq = 0.5 * fs
normal_cutoff = cutoff / nyq

b, a = butter(order, normal_cutoff, btype='low', analog=False)
sig3 = 1-lfilter(b, a, sig2)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(12, 6))
fig.suptitle('Simulation of the Analog-Digital signal using Pulse Code Modulation.', fontsize=18)


ax[0, 0].plot(t,sig0,label='Input Signal', color='y')
ax[0, 0].grid()
ax[0, 0].legend(loc='upper right')
ax[0, 0].set_ylabel("Amplitude")
ax[0 ,0].set_xlabel("Time")


ax[0, 1].plot(t,np.abs(sig1/q),label='Quatization Signal', color='r')
ax[0, 1].legend(loc='upper right')
ax[0, 1].set_ylabel("Amplitude")
ax[0 ,1].set_xlabel("Time")


print('Binary Serial Output')
print(tx)


ax[1, 0].plot(t,sig2,label='Binary Decoded Output', color='b')
ax[1, 0].legend(loc='upper right')
ax[1, 0].set_ylabel("Amplitude")


ax[-1 ,-1].plot(t,sig3,label='Low Pass filtered Output', color='m')
ax[-1 ,-1].legend(loc='upper right')
ax[-1 ,-1].set_ylabel("Amplitude")
ax[-1 ,-1].set_xlabel("Time")
# Out:
# Binary Serial Output
# ['0100' '0100' '0100' ... '0100' '0100' '0100']
# Text(0.5, 0, 'Time')

# %% [markdown]
# # **Task #02**
#
# ### **A program to simulate the digital-digital conversion techniques (Line Coding and Decoding, Block Coding and Decoding Schemes).**

# %% [markdown]
# ### **Line coding Program**

# %%
#@title prerequisites
sns.set()
#plt.style.use('dark_background')
plt.rcParams['figure.figsize']=(15,3)
# bit_seq=input("Enter the digital data (bit sequence): ")

mB = 4
nB = 5
block_coding_mapping_codes = {
# encoding map
"0000": "11110",
"0001": "01001",
"0010": "10100",
"0011": "10101",
"0100": "01010",
"0101": "01011",
"0110": "01110",
"0111": "01111",
"1000": "10010",
"1001": "10011",
"1010": "10110",
"1011": "10111",
"1100": "11010",
"1101": "11011",
"1110": "11100",
"1111": "11101",
# decoding map
"11110": "0000",
"01001": "0001",
"10100": "0010",
"10101": "0011",
"01010": "0100",
"01011": "0101",
"01110": "0110",
"01111": "0111",
"10010": "1000",
"10011": "1001",
"10110": "1010",
"10111": "1011",
"11010": "1100",
"11011": "1101",
"11100": "1110",
"11101": "1111",

}

# %%
#@title Line Coding Functions
def UnipolarNRZ(bit_seq):
    t=[]
    amp=[]
    x=[]
    dt = {'1':5, '0':0}

    for i in range(0, len(bit_seq)):
        t.append(i)
        x.append(i)
    t.append(i+1)
    x.append(i+1)

    for i in range(0, len(bit_seq)):
        amp.append(dt[bit_seq[i]])
    amp.append(0)

    plt.figure()
    plt.hlines(0, t[0], t[len(t)-1]+1, colors='b')
    plt.plot(t, amp, drawstyle='steps-post', linewidth=5.0, color='k')
    plt.xticks(x)
    plt.yticks([0, 5])
    plt.grid(b=True, color='g', linestyle='--', linewidth=2.0, axis='x')
    plt.show()

def UnipolarRZ(bit_seq):
    t=[]
    amp=[]
    x=[]

    for i in range(0, len(bit_seq)):
        t.append(i)
        x.append(i)
        if bit_seq[i]=='1':
            t.append(i+0.5)
    t.append(i+1)
    x.append(i+1)

    for i in range(0, len(bit_seq)):
        if bit_seq[i]=='0':
            amp.append(0)
        else:
            amp.append(5)
            amp.append(0)
    amp.append(0)

    plt.figure()
    plt.hlines(0, t[0], t[len(t)-1]+1, colors='b', linewidth=5.0)
    plt.plot(t, amp, drawstyle='steps-post', linewidth=5.0, color='k')
    plt.xticks(x)
    plt.yticks([0, 5])
    plt.grid(b=True, color='g', linestyle='--', linewidth=2.0, axis='x')
    plt.show()
    
def PolarNRZL(bit_seq):
	t=[]
	amp=[]
	x=[]
	dt = {'1':5, '0':-5}

	for i in range(0, len(bit_seq)):
		x.append(i)
		t.append(i)
		
	t.append(i+1)
	x.append(i+1)

	for i in range(0, len(bit_seq)):
	    amp.append(dt[bit_seq[i]])
	amp.append(0)

	plt.figure()
	plt.hlines(0, t[0], t[len(t)-1]+1, colors='b', linewidth=5.0)
	plt.plot(t, amp, drawstyle='steps-post', linewidth=5.0, color='k')
	plt.xticks(x)
	plt.yticks([0, 5, -5])
	plt.grid(b=True, color='g', linestyle='--', linewidth=2.0, axis='x')
	plt.show()

def PolarNRZI(bit_seq):
    t=[]
    amp=[]
    x=[]

    for i in range(0, len(bit_seq)):
        t.append(i)
        x.append(i)
    t.append(i+1)
    x.append(i+1)
    
    prev = -5
    
    for i in range(0, len(bit_seq)):
        if  bit_seq[i]=='1':
            if prev==5:
                amp.append(-5)
                prev=-5
            else:
                amp.append(5)
                prev=5
        else:
            amp.append(prev)
    amp.append(0)

    plt.figure()
    plt.hlines(0, t[0], t[len(t)-1]+1, colors='b', linewidth=5.0)
    plt.plot(t, amp, drawstyle='steps-post', linewidth=5.0, color='k')
    plt.xticks(x)
    plt.yticks([0, 5, -5])
    plt.grid(b=True, color='g', linestyle='--', linewidth=2.0, axis='x')
    plt.show()

def PolarRZ(bit_seq):
    t=[]
    amp=[]
    x=[]
    dt = {'1':5, '0':-5}

    for i in range(0, len(bit_seq)):
        t.append(i)
        x.append(i)
        t.append(i+0.5)
    t.append(i+1)
    x.append(i+1)

    for i in range(0, len(bit_seq)):
        amp.append(dt[bit_seq[i]])
        amp.append(0)
    amp.append(0)

    plt.figure()
    plt.hlines(0, t[0], t[len(t)-1]+1, colors='b', linewidth=5.0)
    plt.plot(t, amp, drawstyle='steps-post', linewidth=5.0, color='k')
    plt.xticks(x)
    plt.yticks([0, 5, -5])
    plt.grid(b=True, color='g', linestyle='--', linewidth=2.0, axis='x')
    plt.show()

def Manchester(bit_seq):
    t=[]
    amp=[]
    x=[]

    for i in range(0, len(bit_seq)):
        t.append(i)
        x.append(i)
        t.append(i+0.5)
    t.append(i+1)
    x.append(i+1)

    for i in range(0, len(bit_seq)):
        if bit_seq[i]=='0':
            amp.append(-5)
            amp.append(5)
        else:
            amp.append(5)
            amp.append(-5)
    amp.append(0)

    plt.figure()
    plt.hlines(0, t[0], t[len(t)-1]+1, colors='b', linewidth=5.0)
    plt.plot(t, amp, drawstyle='steps-post', linewidth=5.0, color='k')
    plt.xticks(x)
    plt.yticks([0, 5, -5])
    plt.tight_layout(pad=3.0)
    plt.grid(b=True, color='g', linestyle='--', linewidth=2.0, axis='x')
    plt.show()

def DifferentialManchester(bit_seq):
    t=[]
    amp=[]
    x=[]

    for i in range(0, len(bit_seq)):
        t.append(i)
        x.append(i)
        t.append(i+0.5)
    t.append(i+1)
    x.append(i+1)
    
    prev=5
    for i in range(0, len(bit_seq)):
        if bit_seq[i]=='0':
            if prev==5:
                amp.append(-5)
                amp.append(5)
                prev=5
            else:
                amp.append(5)
                amp.append(-5)
                prev=-5
        else:
            if prev==5:
                amp.append(5)
                amp.append(-5)
                prev=-5
            else:
                amp.append(-5)
                amp.append(5)
                prev=5
                
    amp.append(0)

    plt.figure()
    plt.hlines(0, t[0], t[len(t)-1]+1, colors='b', linewidth=5.0)
    plt.plot(t, amp, drawstyle='steps-post', linewidth=5.0, color='k')
    plt.xticks(x)
    plt.yticks([0, 5, -5])
    plt.tight_layout(pad=3.0)
    plt.grid(b=True, color='g', linestyle='--', linewidth=2.0, axis='x')
    plt.show()

def BipolarAMI(bit_seq):
    t=[]
    amp=[]
    x=[]

    for i in range(0, len(bit_seq)):
        t.append(i)
        x.append(i)
    t.append(i+1)
    x.append(i+1)
    
    prev=-5
    for i in range(0, len(bit_seq)):
        if bit_seq[i]=='1':
            if prev==5:
                amp.append(-5)
                prev=-5
            else:
                amp.append(5)
                prev=5
        else:
            amp.append(0)
    amp.append(0)

    plt.figure()
    plt.hlines(0, t[0], t[len(t)-1]+1, colors='b', linewidth=5.0)
    plt.plot(t, amp, drawstyle='steps-post', linewidth=5.0, color='k')
    plt.xticks(x)
    plt.yticks([-5,0, 5])
    plt.grid(b=True, color='g', linestyle='--', linewidth=2.0, axis='x')
    plt.show()

def BipolarPseudoternary(bit_seq):
    t=[]
    amp=[]
    x=[]

    for i in range(0, len(bit_seq)):
        t.append(i)
        x.append(i)
    t.append(i+1)
    x.append(i+1)
    
    prev=-5
    for i in range(0, len(bit_seq)):
        if bit_seq[i]=='0':
            if prev==5:
                amp.append(-5)
                prev=-5
            else:
                amp.append(5)
                prev=5
        else:
            amp.append(0)
    amp.append(0)

    plt.figure()
    plt.hlines(0, t[0], t[len(t)-1]+1, colors='b', linewidth=5.0)
    plt.plot(t, amp, drawstyle='steps-post', linewidth=5.0, color='k')
    plt.xticks(x)
    plt.yticks([-5,0, 5])
    plt.grid(b=True, color='g', linestyle='--', linewidth=2.0, axis='x')
    plt.show()

# %%
#@title Encoding and Encoding Functions for 4B/5B Block Coding
def get_Mapping_Codes(bits):
    return block_coding_mapping_codes["".join(map(str, bits))]
  
'''
bits = sequence of bits to encoded using mB/nB
'''
def get_MB_NB_Encoding(bits, mB, nB):
    # If the length of bits is not multiple of mB, appends extra 0's at the end of the bits(optional)
    if len(bits) % mB != 0:
      # Necessary bit count to make it multiple of mB
      extra_len = (((len(bits)// mB) + 1) * mB) - len(bits)
      extra = np.array(np.zeros(extra_len), dtype=int)
      bits = np.append(bits, extra)
    
    encoded_bits_str = ""
    for i in range(0, len(bits), mB):
      encoded_bits_str += get_Mapping_Codes(bits[i:i+mB])
    
    # Convert the encoded bit string to list of bits
    encoded_bits_list = list(encoded_bits_str)
    encoded_bits_map = map(int, encoded_bits_list)
    encoded_bits = np.array(list(encoded_bits_map))
    return encoded_bits

'''
bits = sequence of bits to decoded using mB/nB
'''
def get_NB_MB_Decoding(bits, mB, nB):
    if len(bits) % nB != 0:
      print("Invalid length, Decoding Not possible!")
      return
    decoded_bits_str = ""
    for i in range(0, len(bits), nB):
      decoded_bits_str += get_Mapping_Codes(bits[i:i+nB])
    # Convert the decoded bit string to list of bits
    decoded_bits_list = list(decoded_bits_str)
    decoded_bits_map = map(int, decoded_bits_list)
    decoded_bits = np.array(list(decoded_bits_map))
    return decoded_bits

def PolarNRZIDecoding(bits):
    Time = 10e-6   
    bit_rate = 1/Time  
    Fs = 4*bit_rate    
    N = len(bits)   
    T = np.linspace(0,Time, mB * 100)

    x = np.array([])
    last_bit = 1
    for i in range(N):
      if bits[i] == 1:
        temp = (-1) * last_bit * np.ones(len(T))
        last_bit = -last_bit
      else:
        temp = last_bit * np.ones(len(T))
      x = np.append(x, temp)
    t = np.linspace(0,N*Time,len(x))
    result = []
    counter = 0
    last_bit = 1
    for i in range(len(t)):
      if t[i]*bit_rate > counter:
        counter = counter + 1
        if x[i] != last_bit:
          result.append(1)
          last_bit=-last_bit
        else:
          result.append(0)
    return result

def Encodingwith4b5b(bit_seq):
    bits = list(map(int, bit_seq))
    bits = get_MB_NB_Encoding(bits, mB, nB)

    str1 = ''.join(str(e) for e in bits)
    PolarNRZI(str1) 

    loop=True  
    while loop:
        print("Do you want to decode now?:- ")
        print("1. 4B/5B Decoding")
        print("2. Exit")

        option=int(input("Enter your choice>>> "))

        if option==1:
            Decodingwith4b5b(bit_seq, mB, nB)
            loop=False  


def Decodingwith4b5b(bit_seq, mB, nB):

    bits=list(map(int, bit_seq.split(" ")))
    bits = list(map(int, bit_seq))
    bits = get_MB_NB_Encoding(bits, mB, nB)

    result = PolarNRZIDecoding(bits)
    print('Decoded by NRZ-I line coding:', result)

    decoded_result = get_NB_MB_Decoding(result, mB, nB)
    print('4B/5B Decoded result', decoded_result)

# %%
def main():
    
    loop=True

    while loop:
        print("Choose the Line encoding type :")
        print("1. Unipolar NRZ")
        print("2. Unipolar RZ")
        print("3. Polar-NRZ-L")
        print("4. Polar-NRZ-I")
        print("5. Polar-RZ")
        print("6. Manchester")
        print("7. Differential Manchester")
        print("8. Bipolar AMI")
        print("9. Bipolar Pseudoternary")
        print("10. 4B/5B Encoding and Decoding")
        print("11. Exit")

        option=int(input("Enter your choice>>> "))

        if option==1:
            UnipolarNRZ(bit_seq)
        
        elif option==2:
            UnipolarRZ(bit_seq)

        elif option==3:
            PolarNRZL(bit_seq)

        elif option==4:
            PolarNRZI(bit_seq)

        elif option==5:
            PolarRZ(bit_seq)

        elif option==6:
            Manchester(bit_seq)

        elif option==7:
            DifferentialManchester(bit_seq)

        elif option==8:
            BipolarAMI(bit_seq)

        elif option==9:
            BipolarPseudoternary(bit_seq)

        elif option==10:
            Encodingwith4b5b(bit_seq)
            
        else:
            loop=False  

bit_seq=input("Enter the digital data (bit sequence): ")
main()
# Out:
# Enter the digital data (bit sequence): 1010110
# Choose the Line encoding type :
# 1. Unipolar NRZ
# 2. Unipolar RZ
# 3. Polar-NRZ-L
# 4. Polar-NRZ-I
# 5. Polar-RZ
# 6. Manchester
# 7. Differential Manchester
# 8. Bipolar AMI
# 9. Bipolar Pseudoternary
# 10. 4B/5B Encoding and Decoding
# 11. Exit
# Enter your choice>>> 4
# Choose the Line encoding type :
# 1. Unipolar NRZ
# 2. Unipolar RZ
# 3. Polar-NRZ-L
# 4. Polar-NRZ-I
# 5. Polar-RZ
# 6. Manchester
# 7. Differential Manchester
# 8. Bipolar AMI
# 9. Bipolar Pseudoternary
# 10. 4B/5B Encoding and Decoding
# 11. Exit
# Enter your choice>>> 6
# Choose the Line encoding type :
# 1. Unipolar NRZ
# 2. Unipolar RZ
# 3. Polar-NRZ-L
# 4. Polar-NRZ-I
# 5. Polar-RZ
# 6. Manchester
# 7. Differential Manchester
# 8. Bipolar AMI
# 9. Bipolar Pseudoternary
# 10. 4B/5B Encoding and Decoding
# 11. Exit
# Enter your choice>>> 10
# Do you want to decode now?:-
# 1. 4B/5B Decoding
# 2. Exit
# Enter your choice>>> 1
# ...

# %% [markdown]
# # **Task #03**
#
# ### **A program to simulate the digital-analog conversion techniques (ASK,FSK, PSK).**

# %% [markdown]
# #### **Amplitude Shift Keying**

# %%
v = input('Enter digital data:- ')
v = list(map(int, v))

dim=100
Vx=[]
for i in range (0,len(v)):
    f=np.ones(dim)
    x=f*v[i]
    Vx=np.concatenate((Vx,x))

fig = plt.figure(figsize = (10, 8))
fig.suptitle('Amplitude Shift Keying', y=1.05, fontsize=18)

plt.subplot(3,1,1)
plt.plot(Vx,'g')
plt.title("Message Signal")
plt.ylabel('Xm(t)')
dim2=len(Vx)

t=np.linspace(0,5,dim2)
plt.subplot(3,1,2)
y1=np.cos(2*np.pi*10*t)
plt.plot(t,y1,'b')
plt.title("Carrier Signal")
plt.ylabel('Fc(t)')

plt.subplot(3,1,3)
mult=(Vx*y1)
plt.plot(t,mult,'k')
plt.title("ASK Modulated Signal")
plt.ylabel('Ym(t)')

fig.tight_layout(pad=2.0)
plt.show()
# Out:
# Enter digital data:- 1010110

# %% [markdown]
# ### **Frequency Shift Keying**

# %%
v = input('Enter digital data:- ')
v = list(map(int, v))

dim=100
Vx=[]
Di=[]

for i in range (0,len(v)):
    f=np.ones(dim)
    x=f*v[i]
    Vx=np.concatenate((Vx,x))


fig = plt.figure(figsize = (10, 10))
fig.suptitle('Frequency Shift Keying', y=1.05, fontsize=18)

plt.subplot(4,1,1)
plt.plot(Vx, 'g')
plt.title("Message Signal")
plt.ylabel('Xm(t)')
dim2=len(Vx)

t=np.linspace(0,5,dim2)
plt.subplot(4,1,2)
w1=2*np.pi*5*t
y1=np.cos(w1)
plt.plot(t,y1, 'b')

plt.title("1st Carrier Signal")
plt.ylabel('Fc1(t)')
plt.subplot(4,1,3)
y2=np.cos(2*np.pi*20*t)
plt.plot(t,y2, 'b')

plt.title("2nd Carrier Signal")
plt.ylabel('Fc2(t)')
plt.subplot(4,1,4)

for i in range(0,dim2):
    if Vx[i]==0:
        cero=np.array([y1[i]])
        Di=np.concatenate((Di,cero))
    else:
        uno=np.array([y2[i]])
        Di=np.concatenate((Di,uno))
plt.plot(t,Di, 'k')
plt.title("FSK Modulated Signal")
plt.ylabel('Ym(t)')

fig.tight_layout(pad=1.0)
plt.show()
# Out:
# Enter digital data:- 1010110

# %% [markdown]
# ### **Phase Shift Keying**

# %%
v = input('Enter digital data:- ')
v = list(map(int, v))

dim=100
Vx=[]
Di=[]
#Ciclo para crear la trama de datos digitales
for i in range (1,len(v)):
    f=np.ones(dim)
    x=f*v[i]
    Vx=np.concatenate((Vx,x))


fig = plt.figure(figsize = (10, 10))
fig.suptitle('Phase Shift Keying', y=1.05, fontsize=18)

plt.subplot(4,1,1)
plt.plot(Vx, 'g')
plt.title("Message signal")
plt.ylabel('Xm(t)')
dim2=len(Vx)

t=np.linspace(0,5,dim2)
plt.subplot(4,1,2)
y1=np.cos(2*np.pi*3*t)
plt.plot(t,y1, 'b')

plt.title("Phase 0 Carrier Signal")
plt.ylabel('Fc1(t)')
plt.subplot(4,1,3)
y2=np.sin(2*np.pi*3*t)
plt.plot(t,y2, 'b')

plt.title("Phase 180 Carrier Signal")
plt.ylabel('Fc2(t)')
plt.subplot(4,1,4)
res=((y2*Vx)-(y1*Vx)+(y1))
plt.plot(t,res, 'k')

plt.title("PSK Modulated Signal")
plt.ylabel('Ym(t)')

fig.tight_layout(pad=1.0)
plt.show()
# Out:
# Enter digital data:- 1010110

# %% [markdown]
# # **Task #04**
#
# ### **A program to simulate the analog-analog conversion techniques (Modulation techniques - FM, AM, PM).**

# %% [markdown]
# #### **Frequency Modulation**

# %%
f_m = float(input('Enter modulator frequency: '))
f_c = float(input('Enter carrier frequency: '))
modulation_index = float(input('Enter modulation index: '))

t = np.linspace(0, 1, 1000)
modulator = np.sin(2.0 * np.pi * f_m * t) * modulation_index
carrier = np.sin(2.0 * np.pi * f_c * t)
product = np.zeros_like(modulator)

for i, t in enumerate(t):
    product[i] = np.sin(2. * np.pi * (f_c * t + modulator[i]))

fig = plt.figure(figsize = (10, 8))
fig.suptitle('Frequency Modulation', y=1.03, fontsize=18)

plt.subplot(3, 1, 1)
plt.title('Modulator signal')
plt.plot(modulator,'g')
plt.ylabel('Amplitude')

plt.subplot(3, 1, 2)
plt.title('Carrier signal')
plt.plot(carrier,'b')
plt.ylabel('Amplitude')

plt.subplot(3, 1, 3)
plt.title('FM signal')
plt.plot(product,'k')
plt.ylabel('Amplitude')


fig.tight_layout(pad=2)
plt.show()
# Out:
# Enter modulator frequency: 4
# Enter carrier frequency: 40
# Enter modulation index: 1

# %% [markdown]
# #### **Amplitude Modulation**

# %%
f_m = float(input('Enter modulator frquency: '))
f_c = float(input('Enter carrier frquency: '))
modulation_index = float(input('Enter modulation index: '))

t = np.linspace(0, 1, 1000)

carrier = np.cos(2*np.pi*f_c*t)
modulator = np.cos(2*np.pi*f_m*t)
product = (1+modulation_index*np.cos(2*np.pi*f_m*t))*np.cos(2*np.pi*f_c*t)

fig = plt.figure(figsize = (10, 8))
fig.suptitle('Amplitude Modulation', y=1.05, fontsize=18)

plt.subplot(3,1,1)
plt.title('Modulator Signal')
plt.ylabel('Amplitude')
plt.plot(modulator,'g')

plt.subplot(3,1,2)
plt.title('Carrier Signal')
plt.ylabel('Amplitude')
plt.plot(carrier, 'b')

plt.subplot(3,1,3)
plt.title('AM Modulated Signal')
plt.ylabel('Amplitude')
plt.plot(product, 'k')

fig.tight_layout(pad=2)
plt.show()
# Out:
# Enter modulator frquency: 4
# Enter carrier frquency: 40
# Enter modulation index: 1

# %% [markdown]
# #### **Phase Modulation**

# %%
f_m = float(input('Enter modulator frquency: '))
f_c = float(input('Enter carrier frquency: '))
modulation_index = float(input('Enter modulation index: '))

t = np.linspace(0, 1, 1000)


y1 = np.sin(2*np.pi*f_m*t);
y2 = np.sin(2*np.pi*f_c*t);
y3 = np.cos(2*np.pi*f_c*t+5*modulation_index*y1)

fig = plt.figure(figsize = (10, 8))
fig.suptitle('Phase Modulation', y=1.05, fontsize=18)

plt.subplot(3, 1, 1)
plt.title('Modulator Signal')
plt.plot(t, y1, 'g')
plt.ylabel('Amplitude')


plt.subplot(3, 1, 2)
plt.title('Carrier Signal')
plt.plot(t, y2, 'b')
plt.ylabel('Amplitude')

plt.subplot(3, 1, 3)
plt.title('PM Modulated Signal')
plt.plot(t, y3, 'k')
plt.ylabel('Amplitude')

fig.tight_layout(pad=2)
plt.show()
# Out:
# Enter modulator frquency: 4
# Enter carrier frquency: 40
# Enter modulation index: 1

# %% [markdown]
# # **Task #05**
#
# ### **Read and Try to understand and run the programs from the following link:**
# [https://inst.eecs.berkeley.edu/~ee123/sp15/lab/lab6/Pre-Lab6-Intro-to-Digital-Communications.html](https://inst.eecs.berkeley.edu/~ee123/sp15/lab/lab6/Pre-Lab6-Intro-to-Digital-Communications.html)

# %%
# %pylab
# Import functions and libraries
import numpy as np
import matplotlib.pyplot as plt
import threading,time
import sys

from numpy import pi
from numpy import sin
from numpy import zeros
from numpy import r_
from scipy import signal
from scipy import integrate

import threading,time
import multiprocessing

from numpy import mean
from numpy import power
from numpy.fft import fft
from numpy.fft import fftshift
from numpy.fft import ifft
from numpy.fft import ifftshift
from  scipy.io.wavfile import read as wavread


# %matplotlib inline
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['fft']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
# Plot an image of the spectrogram y, with the axis labeled with time tl,
# and frequency fl
#
# t_range -- time axis label, nt samples
# f_range -- frequency axis label, nf samples
# y -- spectrogram, nf by nt array
# dbf -- Dynamic range of the spect

def sg_plot( t_range, f_range, y, dbf = 60) :
    eps = 1e-3
    
    # find maximum
    y_max = abs(y).max()
    
    # compute 20*log magnitude, scaled to the max
    y_log = 20.0 * np.log10( abs( y ) / y_max + eps )
    
    fig=figure(figsize=(15,6))
    
    plt.imshow( np.flipud( 64.0*(y_log + dbf)/dbf ), extent= t_range  + f_range ,cmap=plt.cm.gray, aspect='auto')
    plt.xlabel('Time, s')
    plt.ylabel('Frequency, Hz')
    plt.tight_layout()


def myspectrogram_hann_ovlp(x, m, fs, fc,dbf = 60):
    # Plot the spectrogram of x.
    # First take the original signal x and split it into blocks of length m
    # This corresponds to using a rectangular window %
    
    
    isreal_bool = isreal(x).all()
    
    # pad x up to a multiple of m 
    lx = len(x);
    nt = (lx + m - 1) // m
    x = append(x,zeros(-lx+nt*m))
    x = x.reshape((m//2,nt*2), order='F')
    x = concatenate((x,x),axis=0)
    x = x.reshape((m*nt*2,1),order='F')
    x = x[r_[m//2:len(x),ones(m//2)*(len(x)-1)].astype(int)].reshape((m,nt*2),order='F')
    
    
    xmw = x * hanning(m)[:,None];
    
    
    # frequency index
    t_range = [0.0, lx / fs]
    
    if isreal_bool:
        f_range = [ fc, fs / 2.0 + fc]
        xmf = np.fft.fft(xmw,len(xmw),axis=0)
        sg_plot(t_range, f_range, xmf[0:m//2,:],dbf=dbf)
        print (1)
    else:
        f_range = [-fs / 2.0 + fc, fs / 2.0 + fc]
        xmf = np.fft.fftshift( np.fft.fft( xmw ,len(xmw),axis=0), axes=0 )
        sg_plot(t_range, f_range, xmf,dbf = dbf)
    
    return t_range, f_range, xmf

# %%
fs = 44100  # sampling rate
baud = 300  # symbol rate
Nbits = 10  # number of bits
Ns = int(fs/baud)
N = Nbits * Ns
f0 = 1800
bits = randn(Nbits,1) > 0

# %%
np.random.seed(seed=1)
bits = randn(Nbits,1) > 0
M = np.tile(bits,(1,Ns))
t = r_[0.0:N]/fs
OOK = M.ravel()*sin(2*pi*f0*t)

fig = figure(figsize = (16,4))
plot(t,OOK)
xlabel('time [s]')
title('OOK signal of the sequence:'+ np.array2string(transpose(np.uint8(bits))))
# Out:
# Text(0.5, 1.0, 'OOK signal of the sequence:[[1 0 0 0 1 0 1 0 1 0]]')

# %%
f = r_[0:N/2.0]/N*fs

OOK_f = (np.fft.fft(OOK))

fig = figure(figsize = (16,4))
plot(f,abs(OOK_f[:len(OOK_f)//2]))
xlabel('frequency [Hz]')
title('Spectrum of an OOK signal ')
axis((0,4096,0,max(abs(OOK_f))))
# Out:
# (0.0, 4096.0, 0.0, 294.0)

# %%
imp = zeros(N)
imp[::Ns] = bits.ravel()

h = signal.firwin(Ns*4,1.0/Ns)
imp_sinc = signal.fftconvolve(imp,h,mode='full')
t = r_[0.0:len(imp_sinc)]/fs
OOK_s = imp_sinc*sin(2*pi*f0*t)


fig = figure(figsize = (16,4))
plot(t,OOK_s)
xlabel('time [s]')
title('TBW=4 shaped OOK/ASK signal of the sequence:'+ np.array2string(transpose(np.uint8(bits))))

f = r_[0:len(imp_sinc)/2.0]/len(imp_sinc)*fs
OOK_sf = (np.fft.fft(OOK_s))

fig = figure(figsize = (16,4))
plot(f,abs(OOK_sf[0:len(OOK_sf)//2+1]))
xlabel('frequency [Hz]')
title('Spectrum of an pulse shaped OOK signal ')
axis((0,4096,0,max(abs(OOK_sf))))
# Out:
# (0.0, 4096.0, 0.0, 1.9970256011631373)

# %%
np.random.seed(seed=1)
bits = randn(Nbits,1) > 0 
M = np.tile(bits*2-1,(1,Ns))
t = r_[0.0:N]/fs
BPSK = M.ravel()*sin(2*pi*f0*t)

fig = figure(figsize = (16,4))
plot(t,BPSK)
xlabel('time [s]')
title('BPSK signal of the sequence:'+ np.array2string(transpose(np.uint8(bits))))
# Out:
# Text(0.5, 1.0, 'BPSK signal of the sequence:[[1 0 0 0 1 0 1 0 1 0]]')

# %%
f = r_[0:N/2.0]/N*fs

BPSK_f = (np.fft.fft(BPSK))

fig = figure(figsize = (16,4))
plot(f,abs(BPSK_f[0:len(BPSK_f)//2]))
xlabel('frequency [Hz]')
title('Spectrum of a BPSK signal ')
axis((0,4096,0,max(abs(BPSK_f))))
# Out:
# (0.0, 4096.0, 0.0, 390.26447963622365)

# %%
imp = zeros(N)
imp[::Ns] = bits.ravel()*2-1

h = signal.firwin(Ns*4,1.0/Ns)
imp_sinc = signal.fftconvolve(imp,h,mode='full')
t = r_[0.0:len(imp_sinc)]/fs
BPSK_s = imp_sinc*sin(2*pi*f0*t)


fig = figure(figsize = (16,4))
plot(t,BPSK_s)
xlabel('time [s]')
title('TBW=4 shaped BPSK signal of the sequence:'+ np.array2string(transpose(np.uint8(bits))))

f = r_[0:len(imp_sinc)/2.0]/len(imp_sinc)*fs
BPSK_sf = (np.fft.fft(BPSK_s))

fig = figure(figsize = (16,4))
plot(f,abs(BPSK_sf[0:len(BPSK_sf)//2+1]))
xlabel('frequency [Hz]')
title('Spectrum of a pulse shaped BPSK signal ')
axis((0,4096,0,max(abs(BPSK_sf))))
# Out:
# (0.0, 4096.0, 0.0, 2.0076543433726286)

# %%
#code = { 2: -2+2j, 6: -1+2j, 14: 1+2j, 10: 2+2j,
#        3: -2+1j, 7: -1-1j, 15: 1+1j, 11: 2+1j,
#        1: -2-1j, 5: -1-1j, 13: 1-1j, 9: 2-1j,
#        0: -2-2j, 4: -1-2j, 12: 1-2j, 8: 2-2j}
Nbits = 16  # number of bits
N = Nbits * Ns
code = np.array((-2-2j, -2-1j,-2+2j,-2+1j,-1-2j,-1-1j,-1+2j,-1+1j,+2-2j,+2-1j,+2+2j,+2+1j,1-2j,+1-1j,1+2j,1+1j))/2
np.random.seed(seed=1)
bits = np.int16(rand(Nbits,1)*16) 
M = np.tile(code[bits],(1,Ns))
t = r_[0.0:N]/fs

# these are two ways of producing the same result:
#QAM = (M.real.ravel()*cos(2*pi*f0*t) - M.imag.ravel()*sin(2*pi*f0*t))/2/sqrt(2)
QAM = real(M.ravel()*exp(1j*2*pi*f0*t))/sqrt(2)/2
fig = figure(figsize = (16,4))
plot(t,QAM.real)
xlabel('time [s]')
title("QAM=16 of the sequence:"+ np.array2string(transpose(bits)))
# Out:
# Text(0.5, 1.0, 'QAM=16 of the sequence:[[ 6 11  0  4  2  1  2  5  6  8  6 10  3 14  0 10]]')

# %%
f = r_[0:N/2.0]/N*fs

QAM_f = (np.fft.fft(QAM))

fig = figure(figsize = (16,4))
plot(f,abs(QAM_f[0:len(QAM_f)//2]))
xlabel('frequency [Hz]')
title('Spectrum of a QAM16 signal ')
axis((0,4096,0,max(abs(QAM_f))))


imp = zeros(N,dtype='complex')
imp[::Ns] = code[bits].ravel()

h = signal.firwin(Ns*4,1.0/Ns)
imp_sinc = signal.fftconvolve(imp,h,mode='full')
t = r_[0.0:len(imp_sinc)]/fs
QAM_s = real(imp_sinc*exp(1j*2*pi*f0*t))


fig = figure(figsize = (16,4))
plot(t,QAM_s)
xlabel('time [s]')
title('TBW=4 shaped QAM16 signal of the sequence:'+ np.array2string(transpose(bits)))
f = r_[0:len(imp_sinc)/2.0]/len(imp_sinc)*fs
QAM_sf = (np.fft.fft(QAM_s))

fig = figure(figsize = (16,4))
plot(f,abs(QAM_sf[0:len(QAM_sf)//2+1]))
xlabel('frequency [Hz]')
title('Spectrum of a pulse shaped QAM16 signal ')
axis((0,4096,0,max(abs(QAM_sf))))
# Out:
# (0.0, 4096.0, 0.0, 3.2219746046372206)

# %%
np.random.seed(seed=1)
Nbits = 10
N = Nbits * Ns
bits = randn(Nbits,1) > 0 
M = np.tile(bits*2-1,(1,Ns))
delta_f = 600


# compute phase by integrating frequency
ph = 2*pi*cumsum(f0 + M.ravel()*delta_f)/fs
t = r_[0.0:N]/fs
FSK = sin(ph)

fig = figure(figsize = (16,4))
plot(t,FSK)
xlabel('time [s]')
title('FSK signal of the sequence:'+ np.array2string(transpose(np.uint8(bits))))
# Out:
# Text(0.5, 1.0, 'FSK signal of the sequence:[[1 0 0 0 1 0 1 0 1 0]]')

# %%
f = r_[0:N/2.0]/N*fs

FSK_f = (np.fft.fft(FSK))

fig = figure(figsize = (16,4))
plot(f,abs(FSK_f[0:len(FSK_f)//2]))
xlabel('frequency [Hz]')
title('Spectrum of a FSK signal ')
axis((0,4096,0,max(abs(FSK_f))))
# Out:
# (0.0, 4096.0, 0.0, 441.00000000000006)

# %%
delta_f = 150
ph = 2*pi*cumsum(f0 + M.ravel()*delta_f)/fs
t = r_[0.0:N]/fs
MSK = sin(ph)

fig = figure(figsize = (16,4))
plot(t,MSK)
xlabel('time [s]')
title('MSK signal of the sequence:'+ np.array2string(transpose(np.uint8(bits))))

f = r_[0:N/2.0]/N*fs

MSK_f = (np.fft.fft(MSK))

fig = figure(figsize = (16,4))
plot(f,abs(MSK_f[0:len(MSK_f)//2]))
xlabel('frequency [Hz]')
title('Spectrum of a MSK signal ')
axis((0,4096,0,max(abs(MSK_f))))
tt,ff,xmf = myspectrogram_hann_ovlp(MSK, 148, 44100.0, 0,dbf = 60)
title('Spectrogram of MSK')
# Out:
# 1
# Text(0.5, 1.0, 'Spectrogram of MSK')

# %%
TBW =0.5
Tb = 294
B = Tb*TBW
n = r_[-Tb/2:Tb/2]
h = sqrt(2*pi/log(2))*B/fs*exp(-2*pi*pi*B*B*n*n/fs/fs/log(2))


fig = figure(figsize = (16,4))
plot(h)

freq = signal.fftconvolve(f0 + M.ravel()*delta_f,h)
ph = 2*pi*cumsum(freq)/fs
t = r_[0.0:N]/fs
GMSK = sin(ph)

t = r_[0.0:len(GMSK)]/fs
fig = figure(figsize = (16,4))
plot(t,GMSK)
xlabel('time [s]')
title('GMSK signal of the sequence:'+ np.array2string(transpose(np.uint8(bits))))

f = r_[0:len(GMSK)/2.0]/len(GMSK)*fs

GMSK_f = (np.fft.fft(GMSK))

fig = figure(figsize = (16,4))
plot(f,abs(GMSK_f[0:len(GMSK_f)//2+1]))
xlabel('frequency [Hz]')
title('Spectrum of a GMSK signal ')
axis((0,4096,0,max(abs(GMSK_f))))
tt,ff,xmf = myspectrogram_hann_ovlp(GMSK, 148, 44100.0, 0,dbf = 60)
title('Spectrogram of GMSK')
# Out:
# 1
# Text(0.5, 1.0, 'Spectrogram of GMSK')
